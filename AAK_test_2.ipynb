# %%
import pandas as pd
import plotly.express as px
import requests
import duckdb
from pathlib import Path

# %%
data_path = Path('/content/data folder')

bronze_path = data_path / "bronze"
silver_path = data_path / "silver"
gold_path = data_path / "gold"

# %%
duckdb_path = data_path / "worldbank_poplulation_data.duckdb"

duck_conn = duckdb.connect(str(duckdb_path))

# %%
countries_url = 'http://api.worldbank.org/v2/country?format=json&per_page=400'

countries_response = requests.get(countries_url)
countries_json = countries_response.json()


country_rows = countries_json[1] if len(countries_json) > 1 else []

data_raw = pd.json_normalize(country_rows)


data_raw.head()
# Out:
#     id iso2Code                         name capitalCity longitude latitude  \
# 0  ABW       AW                        Aruba  Oranjestad  -70.0167  12.5167
# 1  AFE       ZH  Africa Eastern and Southern
# 2  AFG       AF                  Afghanistan       Kabul   69.1761  34.5228
# 3  AFR       A9                       Africa
# 4  AFW       ZI   Africa Western and Central
#
#   region.id region.iso2code  \
# 0       LCN              ZJ
# 1        NA              NA
# 2       MEA              ZQ
# 3        NA              NA
# 4        NA              NA
#
#                                         region.value adminregion.id  \
# 0                         Latin America & Caribbean
# 1                                         Aggregates
# 2  Middle East, North Africa, Afghanistan & Pakistan            MNA
# 3                                         Aggregates
# 4                                         Aggregates
#
#   adminregion.iso2code                                  adminregion.value  \
# 0
# 1
# 2                   XQ  Middle East, North Africa, Afghanistan & Pakis...
# 3
# 4
#
#   incomeLevel.id incomeLevel.iso2code incomeLevel.value lendingType.id  \
# 0            HIC                   XD       High income            LNX
# 1             NA                   NA        Aggregates
# 2            LIC                   XM        Low income            IDX
# 3             NA                   NA        Aggregates
# 4             NA                   NA        Aggregates
#
#   lendingType.iso2code lendingType.value
# 0                   XX    Not classified
# 1                             Aggregates
# 2                   XI               IDA
# 3                             Aggregates
# 4                             Aggregates

# %%
data_filt = data_raw[data_raw['region.id'] !="NA" ].copy()

data_pick = data_filt[[
    "id",
    "iso2Code",
    "name",
    "capitalCity",
    "longitude",
    "latitude",
    "region.value",
    "incomeLevel.value"
]].rename(columns={
    "id":"iso3",
    "iso2Code":"iso2",
    "name":"Official_Name",
    "region.value":"region_name",
    "incomeLevel.value":"income_level",
    "capitalCity":"capital_city"
})

# %%
population_url = "https://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?format=json&MRV=1&per_page=20000"

population_response = requests.get(population_url)
population_json = population_response.json()

population_rows = population_json[1] if len(population_json) > 1 else []

data_pop = pd.json_normalize(population_rows)

data_pop
# Out:
#     countryiso3code  date        value unit obs_status  decimal indicator.id  \
# 0               AFE  2024  769294618.0                        0  SP.POP.TOTL
# 1               AFW  2024  521764076.0                        0  SP.POP.TOTL
# 2               ARB  2024  492579811.0                        0  SP.POP.TOTL
# 3               CSS  2024    4539060.0                        0  SP.POP.TOTL
# 4               CEB  2024  100050066.0                        0  SP.POP.TOTL
# ..              ...   ...          ...  ...        ...      ...          ...
# 261             VIR  2024     104377.0                        0  SP.POP.TOTL
# 262             PSE  2024    5289152.0                        0  SP.POP.TOTL
# 263             YEM  2024   40583164.0                        0  SP.POP.TOTL
# 264             ZMB  2024   21314956.0                        0  SP.POP.TOTL
# 265             ZWE  2024   16634373.0                        0  SP.POP.TOTL
#
#        indicator.value country.id                   country.value
# 0    Population, total         ZH     Africa Eastern and Southern
# 1    Population, total         ZI      Africa Western and Central
# 2    Population, total         1A                      Arab World
# 3    Population, total         S3          Caribbean small states
# 4    Population, total         B8  Central Europe and the Baltics
# ..                 ...        ...                             ...
# 261  Population, total         VI           Virgin Islands (U.S.)
# 262  Population, total         PS              West Bank and Gaza
# 263  Population, total         YE                     Yemen, Rep.
# 264  Population, total         ZM                          Zambia
# 265  Population, total         ZW                        Zimbabwe
#
# [266 rows x 10 columns]

# %%
data_pop_clean = data_pop[["countryiso3code", "date", "value"]].rename(columns={
    "countryiso3code":"iso3",
    "date":"population_year",
    "value":"population"
})

data_pop_filt = data_pop_clean.dropna(subset=["iso3"])

# %%
data_pop_fixed = data_pop_filt.assign(

      population = pd.to_numeric(data_pop_filt["population"], errors= "coerce"),
      population_year = pd.to_numeric(data_pop_filt["population_year"], errors= "coerce")

).dropna(subset=["population","population_year"])

# %%
bronze_df = data_pick.merge(data_pop_fixed, on="iso3", how="left" )
bronze_df["scrape_timesstamp"] = pd.Timestamp.utcnow()

bronze_df
# Out:
#     iso3 iso2 Official_Name      capital_city longitude  latitude  \
# 0    ABW   AW         Aruba        Oranjestad  -70.0167   12.5167
# 1    AFG   AF   Afghanistan             Kabul   69.1761   34.5228
# 2    AGO   AO        Angola            Luanda    13.242  -8.81155
# 3    ALB   AL       Albania            Tirane   19.8172   41.3317
# 4    AND   AD       Andorra  Andorra la Vella    1.5218   42.5075
# ..   ...  ...           ...               ...       ...       ...
# 212  XKX   XK        Kosovo          Pristina    20.926    42.565
# 213  YEM   YE   Yemen, Rep.            Sana'a   44.2075    15.352
# 214  ZAF   ZA  South Africa          Pretoria   28.1871   -25.746
# 215  ZMB   ZM        Zambia            Lusaka   28.2937  -15.3982
# 216  ZWE   ZW      Zimbabwe            Harare   31.0672  -17.8312
#
#                                            region_name         income_level  \
# 0                           Latin America & Caribbean           High income
# 1    Middle East, North Africa, Afghanistan & Pakistan           Low income
# 2                                  Sub-Saharan Africa   Lower middle income
# 3                                Europe & Central Asia  Upper middle income
# 4                                Europe & Central Asia          High income
# ..                                                 ...                  ...
# 212                              Europe & Central Asia  Upper middle income
# 213  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 214                                Sub-Saharan Africa   Upper middle income
# 215                                Sub-Saharan Africa   Lower middle income
# 216                                Sub-Saharan Africa   Lower middle income
#
#      population_year  population                scrape_timesstamp
# 0               2024    107624.0 2025-11-12 20:41:08.364617+00:00
# 1               2024  42647492.0 2025-11-12 20:41:08.364617+00:00
# 2               2024  37885849.0 2025-11-12 20:41:08.364617+00:00
# 3               2024   2714617.0 2025-11-12 20:41:08.364617+00:00
# 4               2024     81938.0 2025-11-12 20:41:08.364617+00:00
# ..               ...         ...                              ...
# 212             2024   1527324.0 2025-11-12 20:41:08.364617+00:00
# 213             2024  40583164.0 2025-11-12 20:41:08.364617+00:00
# 214             2024  64007187.0 2025-11-12 20:41:08.364617+00:00
# 215             2024  21314956.0 2025-11-12 20:41:08.364617+00:00
# 216             2024  16634373.0 2025-11-12 20:41:08.364617+00:00
#
# [217 rows x 11 columns]

# %%
bronze = bronze_path / "country_population_bronze.csv"
bronze_df.to_csv(bronze, index=False)

# %%
duck_conn.execute("CREATE SCHEMA IF NOT EXISTS bronze")
duck_conn.register("bronze_table", bronze_df )
duck_conn.execute("CREATE OR REPLACE TABLE bronze.population AS SELECT * FROM bronze_table")
duck_conn.unregister("bronze_table")

# %%
bronze_pr = duck_conn.execute("SELECT * FROM bronze.population LIMIT 5").df()

# %%
bronze_pr
# Out:
#   iso3 iso2 Official_Name      capital_city longitude  latitude  \
# 0  ABW   AW         Aruba        Oranjestad  -70.0167   12.5167
# 1  AFG   AF   Afghanistan             Kabul   69.1761   34.5228
# 2  AGO   AO        Angola            Luanda    13.242  -8.81155
# 3  ALB   AL       Albania            Tirane   19.8172   41.3317
# 4  AND   AD       Andorra  Andorra la Vella    1.5218   42.5075
#
#                                          region_name         income_level  \
# 0                         Latin America & Caribbean           High income
# 1  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 2                                Sub-Saharan Africa   Lower middle income
# 3                              Europe & Central Asia  Upper middle income
# 4                              Europe & Central Asia          High income
#
#    population_year  population                scrape_timesstamp
# 0             2024    107624.0 2025-11-12 20:41:08.364617+00:00
# 1             2024  42647492.0 2025-11-12 20:41:08.364617+00:00
# 2             2024  37885849.0 2025-11-12 20:41:08.364617+00:00
# 3             2024   2714617.0 2025-11-12 20:41:08.364617+00:00
# 4             2024     81938.0 2025-11-12 20:41:08.364617+00:00

# %%
bronze_df_data = duck_conn.execute("SELECT * FROM bronze.population").df()
bronze_df_data
# Out:
#     iso3 iso2 Official_Name      capital_city longitude  latitude  \
# 0    ABW   AW         Aruba        Oranjestad  -70.0167   12.5167
# 1    AFG   AF   Afghanistan             Kabul   69.1761   34.5228
# 2    AGO   AO        Angola            Luanda    13.242  -8.81155
# 3    ALB   AL       Albania            Tirane   19.8172   41.3317
# 4    AND   AD       Andorra  Andorra la Vella    1.5218   42.5075
# ..   ...  ...           ...               ...       ...       ...
# 212  XKX   XK        Kosovo          Pristina    20.926    42.565
# 213  YEM   YE   Yemen, Rep.            Sana'a   44.2075    15.352
# 214  ZAF   ZA  South Africa          Pretoria   28.1871   -25.746
# 215  ZMB   ZM        Zambia            Lusaka   28.2937  -15.3982
# 216  ZWE   ZW      Zimbabwe            Harare   31.0672  -17.8312
#
#                                            region_name         income_level  \
# 0                           Latin America & Caribbean           High income
# 1    Middle East, North Africa, Afghanistan & Pakistan           Low income
# 2                                  Sub-Saharan Africa   Lower middle income
# 3                                Europe & Central Asia  Upper middle income
# 4                                Europe & Central Asia          High income
# ..                                                 ...                  ...
# 212                              Europe & Central Asia  Upper middle income
# 213  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 214                                Sub-Saharan Africa   Upper middle income
# 215                                Sub-Saharan Africa   Lower middle income
# 216                                Sub-Saharan Africa   Lower middle income
#
#      population_year  population                scrape_timesstamp
# 0               2024    107624.0 2025-11-12 20:41:08.364617+00:00
# 1               2024  42647492.0 2025-11-12 20:41:08.364617+00:00
# 2               2024  37885849.0 2025-11-12 20:41:08.364617+00:00
# 3               2024   2714617.0 2025-11-12 20:41:08.364617+00:00
# 4               2024     81938.0 2025-11-12 20:41:08.364617+00:00
# ..               ...         ...                              ...
# 212             2024   1527324.0 2025-11-12 20:41:08.364617+00:00
# 213             2024  40583164.0 2025-11-12 20:41:08.364617+00:00
# 214             2024  64007187.0 2025-11-12 20:41:08.364617+00:00
# 215             2024  21314956.0 2025-11-12 20:41:08.364617+00:00
# 216             2024  16634373.0 2025-11-12 20:41:08.364617+00:00
#
# [217 rows x 11 columns]

# %%
silver_step = bronze_df_data[bronze_df_data["population"].notna()].copy()

# %%
silver_step
# Out:
#     iso3 iso2 Official_Name      capital_city longitude  latitude  \
# 0    ABW   AW         Aruba        Oranjestad  -70.0167   12.5167
# 1    AFG   AF   Afghanistan             Kabul   69.1761   34.5228
# 2    AGO   AO        Angola            Luanda    13.242  -8.81155
# 3    ALB   AL       Albania            Tirane   19.8172   41.3317
# 4    AND   AD       Andorra  Andorra la Vella    1.5218   42.5075
# ..   ...  ...           ...               ...       ...       ...
# 212  XKX   XK        Kosovo          Pristina    20.926    42.565
# 213  YEM   YE   Yemen, Rep.            Sana'a   44.2075    15.352
# 214  ZAF   ZA  South Africa          Pretoria   28.1871   -25.746
# 215  ZMB   ZM        Zambia            Lusaka   28.2937  -15.3982
# 216  ZWE   ZW      Zimbabwe            Harare   31.0672  -17.8312
#
#                                            region_name         income_level  \
# 0                           Latin America & Caribbean           High income
# 1    Middle East, North Africa, Afghanistan & Pakistan           Low income
# 2                                  Sub-Saharan Africa   Lower middle income
# 3                                Europe & Central Asia  Upper middle income
# 4                                Europe & Central Asia          High income
# ..                                                 ...                  ...
# 212                              Europe & Central Asia  Upper middle income
# 213  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 214                                Sub-Saharan Africa   Upper middle income
# 215                                Sub-Saharan Africa   Lower middle income
# 216                                Sub-Saharan Africa   Lower middle income
#
#      population_year  population                scrape_timesstamp
# 0               2024    107624.0 2025-11-12 20:41:08.364617+00:00
# 1               2024  42647492.0 2025-11-12 20:41:08.364617+00:00
# 2               2024  37885849.0 2025-11-12 20:41:08.364617+00:00
# 3               2024   2714617.0 2025-11-12 20:41:08.364617+00:00
# 4               2024     81938.0 2025-11-12 20:41:08.364617+00:00
# ..               ...         ...                              ...
# 212             2024   1527324.0 2025-11-12 20:41:08.364617+00:00
# 213             2024  40583164.0 2025-11-12 20:41:08.364617+00:00
# 214             2024  64007187.0 2025-11-12 20:41:08.364617+00:00
# 215             2024  21314956.0 2025-11-12 20:41:08.364617+00:00
# 216             2024  16634373.0 2025-11-12 20:41:08.364617+00:00
#
# [217 rows x 11 columns]

# %%
silver_step = silver_step[silver_step["population"] > 0]

# %%
silver_step
# Out:
#     iso3 iso2 Official_Name      capital_city longitude  latitude  \
# 0    ABW   AW         Aruba        Oranjestad  -70.0167   12.5167
# 1    AFG   AF   Afghanistan             Kabul   69.1761   34.5228
# 2    AGO   AO        Angola            Luanda    13.242  -8.81155
# 3    ALB   AL       Albania            Tirane   19.8172   41.3317
# 4    AND   AD       Andorra  Andorra la Vella    1.5218   42.5075
# ..   ...  ...           ...               ...       ...       ...
# 212  XKX   XK        Kosovo          Pristina    20.926    42.565
# 213  YEM   YE   Yemen, Rep.            Sana'a   44.2075    15.352
# 214  ZAF   ZA  South Africa          Pretoria   28.1871   -25.746
# 215  ZMB   ZM        Zambia            Lusaka   28.2937  -15.3982
# 216  ZWE   ZW      Zimbabwe            Harare   31.0672  -17.8312
#
#                                            region_name         income_level  \
# 0                           Latin America & Caribbean           High income
# 1    Middle East, North Africa, Afghanistan & Pakistan           Low income
# 2                                  Sub-Saharan Africa   Lower middle income
# 3                                Europe & Central Asia  Upper middle income
# 4                                Europe & Central Asia          High income
# ..                                                 ...                  ...
# 212                              Europe & Central Asia  Upper middle income
# 213  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 214                                Sub-Saharan Africa   Upper middle income
# 215                                Sub-Saharan Africa   Lower middle income
# 216                                Sub-Saharan Africa   Lower middle income
#
#      population_year  population                scrape_timesstamp
# 0               2024    107624.0 2025-11-12 20:41:08.364617+00:00
# 1               2024  42647492.0 2025-11-12 20:41:08.364617+00:00
# 2               2024  37885849.0 2025-11-12 20:41:08.364617+00:00
# 3               2024   2714617.0 2025-11-12 20:41:08.364617+00:00
# 4               2024     81938.0 2025-11-12 20:41:08.364617+00:00
# ..               ...         ...                              ...
# 212             2024   1527324.0 2025-11-12 20:41:08.364617+00:00
# 213             2024  40583164.0 2025-11-12 20:41:08.364617+00:00
# 214             2024  64007187.0 2025-11-12 20:41:08.364617+00:00
# 215             2024  21314956.0 2025-11-12 20:41:08.364617+00:00
# 216             2024  16634373.0 2025-11-12 20:41:08.364617+00:00
#
# [217 rows x 11 columns]

# %%
silver_clean = silver_step.assign(

      population=silver_step["population"].astype("Int64"),
      population_year=silver_step["population_year"].astype("Int64"),
      population_in_millions=silver_step["population"]/1000000
)

# %%
silver_csv = silver_path / "country_population_silver.csv"
silver_clean.to_csv(silver_csv, index=False)

# %%
duck_conn.execute("CREATE SCHEMA IF NOT EXISTS silver")
duck_conn.register("silver_table", silver_clean )
duck_conn.execute("CREATE OR REPLACE TABLE silver.population AS SELECT * FROM silver_table")
duck_conn.unregister("silver_table")

# %%
silver_from_db = duck_conn.execute("SELECT * FROM silver.population").df()

# %%
gold_sorted = silver_from_db.sort_values(
    ["iso3", "population_year","scrape_timesstamp"],
    ascending = [True, False, False]
)

# %%
gold_latest = gold_sorted.drop_duplicates(subset=["iso3"], keep="first").copy()

# %%
gold_final = gold_latest.assign(
    global_population_share = gold_latest["population"]/gold_latest["population"].sum(),
    population_rank = gold_latest["population"].rank(method = "dense" , ascending=False).astype(int)
)

# %%
gold_final
# Out:
#     iso3 iso2 Official_Name      capital_city longitude  latitude  \
# 0    ABW   AW         Aruba        Oranjestad  -70.0167   12.5167
# 1    AFG   AF   Afghanistan             Kabul   69.1761   34.5228
# 2    AGO   AO        Angola            Luanda    13.242  -8.81155
# 3    ALB   AL       Albania            Tirane   19.8172   41.3317
# 4    AND   AD       Andorra  Andorra la Vella    1.5218   42.5075
# ..   ...  ...           ...               ...       ...       ...
# 212  XKX   XK        Kosovo          Pristina    20.926    42.565
# 213  YEM   YE   Yemen, Rep.            Sana'a   44.2075    15.352
# 214  ZAF   ZA  South Africa          Pretoria   28.1871   -25.746
# 215  ZMB   ZM        Zambia            Lusaka   28.2937  -15.3982
# 216  ZWE   ZW      Zimbabwe            Harare   31.0672  -17.8312
#
#                                            region_name         income_level  \
# 0                           Latin America & Caribbean           High income
# 1    Middle East, North Africa, Afghanistan & Pakistan           Low income
# 2                                  Sub-Saharan Africa   Lower middle income
# 3                                Europe & Central Asia  Upper middle income
# 4                                Europe & Central Asia          High income
# ..                                                 ...                  ...
# 212                              Europe & Central Asia  Upper middle income
# 213  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 214                                Sub-Saharan Africa   Upper middle income
# 215                                Sub-Saharan Africa   Lower middle income
# 216                                Sub-Saharan Africa   Lower middle income
#
#      population_year  population                scrape_timesstamp  \
# 0               2024      107624 2025-11-12 20:41:08.364617+00:00
# 1               2024    42647492 2025-11-12 20:41:08.364617+00:00
# 2               2024    37885849 2025-11-12 20:41:08.364617+00:00
# 3               2024     2714617 2025-11-12 20:41:08.364617+00:00
# 4               2024       81938 2025-11-12 20:41:08.364617+00:00
# ..               ...         ...                              ...
# 212             2024     1527324 2025-11-12 20:41:08.364617+00:00
# 213             2024    40583164 2025-11-12 20:41:08.364617+00:00
# 214             2024    64007187 2025-11-12 20:41:08.364617+00:00
# 215             2024    21314956 2025-11-12 20:41:08.364617+00:00
# 216             2024    16634373 2025-11-12 20:41:08.364617+00:00
#
#      population_in_millions  global_population_share  population_rank
# 0                  0.107624                 0.000013              191
# 1                 42.647492                 0.005253               36
# 2                 37.885849                 0.004667               40
# 3                  2.714617                 0.000334              142
# 4                  0.081938                 0.000010              197
# ..                      ...                      ...              ...
# 212                1.527324                 0.000188              153
# 213               40.583164                 0.004999               38
# 214               64.007187                 0.007884               24
# 215               21.314956                 0.002625               62
# 216               16.634373                 0.002049               73
#
# [217 rows x 14 columns]

# %%
gold_csv = gold_path / "country_population_gold.csv"
gold_final.to_csv(gold_csv, index=False)

# %%
duck_conn.execute("CREATE SCHEMA IF NOT EXISTS gold")
duck_conn.register("gold_table", gold_final )
duck_conn.execute("CREATE OR REPLACE TABLE gold.population_latest AS SELECT * FROM gold_table")
duck_conn.unregister("gold_table")

# %%
gold_top10 = gold_final.sort_values("population", ascending=False).head(10)
print(gold_top10[["Official_Name" , "iso3" , "population" , "population_rank"]])
# Out:
#           Official_Name iso3  population  population_rank
# 89                India  IND  1450935791                1
# 36                China  CHN  1408975000                2
# 203       United States  USA   340110988                3
# 87            Indonesia  IDN   283487931                4
# 150            Pakistan  PAK   251269164                5
# 142             Nigeria  NGA   232679478                6
# 26               Brazil  BRA   211998573                7
# 17           Bangladesh  BGD   173562364                8
# 165  Russian Federation  RUS   143533851                9
# 61             Ethiopia  ETH   132059767               10

# %%
gold_data = duck_conn.execute("SELECT * FROM gold.population_latest").df()

# %%
gold_data
# Out:
#     iso3 iso2 Official_Name      capital_city longitude  latitude  \
# 0    ABW   AW         Aruba        Oranjestad  -70.0167   12.5167
# 1    AFG   AF   Afghanistan             Kabul   69.1761   34.5228
# 2    AGO   AO        Angola            Luanda    13.242  -8.81155
# 3    ALB   AL       Albania            Tirane   19.8172   41.3317
# 4    AND   AD       Andorra  Andorra la Vella    1.5218   42.5075
# ..   ...  ...           ...               ...       ...       ...
# 212  XKX   XK        Kosovo          Pristina    20.926    42.565
# 213  YEM   YE   Yemen, Rep.            Sana'a   44.2075    15.352
# 214  ZAF   ZA  South Africa          Pretoria   28.1871   -25.746
# 215  ZMB   ZM        Zambia            Lusaka   28.2937  -15.3982
# 216  ZWE   ZW      Zimbabwe            Harare   31.0672  -17.8312
#
#                                            region_name         income_level  \
# 0                           Latin America & Caribbean           High income
# 1    Middle East, North Africa, Afghanistan & Pakistan           Low income
# 2                                  Sub-Saharan Africa   Lower middle income
# 3                                Europe & Central Asia  Upper middle income
# 4                                Europe & Central Asia          High income
# ..                                                 ...                  ...
# 212                              Europe & Central Asia  Upper middle income
# 213  Middle East, North Africa, Afghanistan & Pakistan           Low income
# 214                                Sub-Saharan Africa   Upper middle income
# 215                                Sub-Saharan Africa   Lower middle income
# 216                                Sub-Saharan Africa   Lower middle income
#
#      population_year  population                scrape_timesstamp  \
# 0               2024      107624 2025-11-12 20:41:08.364617+00:00
# 1               2024    42647492 2025-11-12 20:41:08.364617+00:00
# 2               2024    37885849 2025-11-12 20:41:08.364617+00:00
# 3               2024     2714617 2025-11-12 20:41:08.364617+00:00
# 4               2024       81938 2025-11-12 20:41:08.364617+00:00
# ..               ...         ...                              ...
# 212             2024     1527324 2025-11-12 20:41:08.364617+00:00
# 213             2024    40583164 2025-11-12 20:41:08.364617+00:00
# 214             2024    64007187 2025-11-12 20:41:08.364617+00:00
# 215             2024    21314956 2025-11-12 20:41:08.364617+00:00
# 216             2024    16634373 2025-11-12 20:41:08.364617+00:00
#
#      population_in_millions  global_population_share  population_rank
# 0                  0.107624                 0.000013              191
# 1                 42.647492                 0.005253               36
# 2                 37.885849                 0.004667               40
# 3                  2.714617                 0.000334              142
# 4                  0.081938                 0.000010              197
# ..                      ...                      ...              ...
# 212                1.527324                 0.000188              153
# 213               40.583164                 0.004999               38
# 214               64.007187                 0.007884               24
# 215               21.314956                 0.002625               62
# 216               16.634373                 0.002049               73
#
# [217 rows x 14 columns]

# %%
region_summary = gold_data.groupby("region_name").agg(
    total_population = ("population", "sum"),
    average_population = ("population", "mean"),
    countries = ("iso3" ,"count")
).reset_index().sort_values("total_population", ascending=False)

# %%
region_summary
# Out:
#                                          region_name  total_population  \
# 0                                East Asia & Pacific        2364965592
# 5                                         South Asia        1677384532
# 6                                Sub-Saharan Africa         1291058694
# 1                              Europe & Central Asia         928465742
# 3  Middle East, North Africa, Afghanistan & Pakistan         813118814
# 2                         Latin America & Caribbean          662185950
# 4                                      North America         381464223
#
#    average_population  countries
# 0        6.391799e+07         37
# 5        2.795641e+08          6
# 6        2.689706e+07         48
# 1        1.600803e+07         58
# 3        3.535299e+07         23
# 2        1.576633e+07         42
# 4        1.271547e+08          3

# %%
region_summary_csv = gold_path / "gold_pipulation_by_region_testing.csv"
region_summary.to_csv(region_summary_csv, index=False)

# %%
top10 = gold_data.sort_values("population", ascending=False).head(10).assign(
    population_text = lambda df: (df["population"] / 1_000_000 ).round(1).astype(str) + "M"
)

top10_chart = px.bar(
    top10,
    x="Official_Name",
    y = "population",
    title="plot1",
    text="population_text"
)
top10_chart.update_layout(xaxis_tickangle=-45)

top10_chart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8d504d43-d002-414c-9c47-e9c19208889e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d504d43-d002-414c-9c47-e9c19208889e")) {                    Plotly.newPlot(                        "8d504d43-d002-414c-9c47-e9c19208889e",                        [{"alignmentgroup":"True","hovertemplate":"Official_Name=%{x}\u003cbr\u003epopulation=%{y}\u003cbr\u003epopulation_text=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["1450.9M","1409.0M","340.1M","283.5M","251.3M","232.7M","212.0M","173.6M","143.5M","132.1M"],"textposition":"auto","x":["India","China","United States","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh","Russian Federation","Ethiopia"],"xaxis":"x","y":[1450935791,1408975000,340110988,283487931,251269164,232679478,211998573,173562364,143533851,132059767],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marke ...

# %%
region_chart = px.bar(
    region_summary,
    x="region_name",
    y = "total_population",
    title="plot2",
    text=(region_summary["total_population"] / 1_000_000_000 ).round(1).astype(str) + "B"

)


region_chart.update_layout(xaxis_tickangle=-45)

region_chart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2f8dcb18-a0b4-49f7-b394-e48d8f471543" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f8dcb18-a0b4-49f7-b394-e48d8f471543")) {                    Plotly.newPlot(                        "2f8dcb18-a0b4-49f7-b394-e48d8f471543",                        [{"alignmentgroup":"True","hovertemplate":"region_name=%{x}\u003cbr\u003etotal_population=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["2.4B","1.7B","1.3B","0.9B","0.8B","0.7B","0.4B"],"textposition":"auto","x":["East Asia & Pacific","South Asia","Sub-Saharan Africa ","Europe & Central Asia","Middle East, North Africa, Afghanistan & Pakistan","Latin America & Caribbean ","North America"],"xaxis":"x","y":[2364965592,1677384532,1291058694,928465742,813118814,662185950,381464223],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"out ...
